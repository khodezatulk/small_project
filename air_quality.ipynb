# %% [markdown]
# <a href="https://colab.research.google.com/github/khodezatulk/small_project/blob/main/air_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/small_project/Air_quality.ipynb" /content/
# !cp "/content/drive/MyDrive/small_project/air-quality-data.csv" /content/

# %%
# %cd /content

# Remove old repo (optional)
# !rm -rf .git

# Initialize Git
# !git init

# Configure your GitHub identity
# !git config --global user.email "bebekhodezatulk@gmail.com"
# !git config --global user.name "khodezatulk"

# Add files
# !git add Air_quality.ipynb air-quality-data.csv README.md
# !git commit -m "Add notebook and dataset"

# Set main branch
# !git branch -M main

# Add remote (without token)
# !git remote add origin https://github.com/khodezatulk/small_project1.git
# Out:
# /content
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# [master (root-commit) 9bc86dd] Add notebook and dataset
#  3 files changed, 31866 insertions(+)
#  create mode 100644 Air_quality.ipynb
#  create mode 100644 README.md
#  create mode 100644 air-quality-data.csv

# %%
# !git config --global credential.helper store

# %% [markdown]
# 1/Show the year-wise avarage polution with line graph
# 2/draw the area plot showing the avarage polution month wise
# 3/draw a ber graph to show the hour wise avarage  pollution.
# 4/Usually which months the air was recorded very unhealthy
# 5/Usually which month the air was recorded very good /fresh
# 6/In the year 2018 how many times AQI was recorded "moderated"
# 7/how was the weather inthe month januarry and july

# %%
import pandas as pd

# %%
file_path = '/content/drive/MyDrive/small_project/air-quality-data.csv'
data = pd.read_csv(file_path)

data
# Out:
#               Timestamp   PM2.5
# 0      01-01-2018 00:00   90.19
# 1      01-01-2018 01:00   86.98
# 2      01-01-2018 02:00   86.06
# 3      01-01-2018 03:00   94.04
# 4      01-01-2018 04:00  108.78
# ...                 ...     ...
# 31856  31-12-2021 19:00   72.25
# 31857  31-12-2021 20:00   71.56
# 31858  31-12-2021 21:00   70.27
# 31859  31-12-2021 22:00   66.78
# 31860  31-12-2021 23:00   61.29
#
# [31861 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31861 entries, 0 to 31860
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  31861 non-null  object
#  1   PM2.5      31861 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 498.0+ KB

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'], errors='coerce', dayfirst=True)
data
# Out:
#                 Timestamp   PM2.5
# 0     2018-01-01 00:00:00   90.19
# 1     2018-01-01 01:00:00   86.98
# 2     2018-01-01 02:00:00   86.06
# 3     2018-01-01 03:00:00   94.04
# 4     2018-01-01 04:00:00  108.78
# ...                   ...     ...
# 31856 2021-12-31 19:00:00   72.25
# 31857 2021-12-31 20:00:00   71.56
# 31858 2021-12-31 21:00:00   70.27
# 31859 2021-12-31 22:00:00   66.78
# 31860 2021-12-31 23:00:00   61.29
#
# [31861 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31861 entries, 0 to 31860
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  31861 non-null  datetime64[ns]
#  1   PM2.5      31861 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 498.0 KB

# %%
data.head()
# Out:
#             Timestamp   PM2.5
# 0 2018-01-01 00:00:00   90.19
# 1 2018-01-01 01:00:00   86.98
# 2 2018-01-01 02:00:00   86.06
# 3 2018-01-01 03:00:00   94.04
# 4 2018-01-01 04:00:00  108.78
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['PM2.5'].plot(kind='hist', bins=20, title='PM2.5')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Timestamp']
#   ys = series['PM2.5']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# ...

# %%
data['Year']=data.Timestamp.dt.year
data
# Out:
#                 Timestamp   PM2.5  year  Year
# 0     2018-01-01 00:00:00   90.19  2018  2018
# 1     2018-01-01 01:00:00   86.98  2018  2018
# 2     2018-01-01 02:00:00   86.06  2018  2018
# 3     2018-01-01 03:00:00   94.04  2018  2018
# 4     2018-01-01 04:00:00  108.78  2018  2018
# ...                   ...     ...   ...   ...
# 31856 2021-12-31 19:00:00   72.25  2021  2021
# 31857 2021-12-31 20:00:00   71.56  2021  2021
# 31858 2021-12-31 21:00:00   70.27  2021  2021
# 31859 2021-12-31 22:00:00   66.78  2021  2021
# 31860 2021-12-31 23:00:00   61.29  2021  2021
#
# [31861 rows x 4 columns]

# %%
data.groupby('Year')
data
# Out:
#                 Timestamp   PM2.5  year  Year
# 0     2018-01-01 00:00:00   90.19  2018  2018
# 1     2018-01-01 01:00:00   86.98  2018  2018
# 2     2018-01-01 02:00:00   86.06  2018  2018
# 3     2018-01-01 03:00:00   94.04  2018  2018
# 4     2018-01-01 04:00:00  108.78  2018  2018
# ...                   ...     ...   ...   ...
# 31856 2021-12-31 19:00:00   72.25  2021  2021
# 31857 2021-12-31 20:00:00   71.56  2021  2021
# 31858 2021-12-31 21:00:00   70.27  2021  2021
# 31859 2021-12-31 22:00:00   66.78  2021  2021
# 31860 2021-12-31 23:00:00   61.29  2021  2021
#
# [31861 rows x 4 columns]

# %%
data.head()
# Out:
#             Timestamp   PM2.5  year  Year
# 0 2018-01-01 00:00:00   90.19  2018  2018
# 1 2018-01-01 01:00:00   86.98  2018  2018
# 2 2018-01-01 02:00:00   86.06  2018  2018
# 3 2018-01-01 03:00:00   94.04  2018  2018
# 4 2018-01-01 04:00:00  108.78  2018  2018

# %%
year_avarage=data.groupby('Year')['PM2.5'].mean()
year_avarage
# Out:
# Year
# 2018    54.468449
# 2019    49.511273
# 2020    42.386302
# 2021    44.850633
# Name: PM2.5, dtype: float64

# %%
# !git add .
# !git commit -m "Add new notebook from Colab"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
